# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
batters = pd.read_csv('Desktop/batter (1).csv')
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.figure(figsize=(15,6))
plt.scatter(batters['avg'],batters['strike_rate'])
plt.title('batters')
plt.xlabel('Avg')
plt.ylabel('Strike_rate')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))
ax.scatter(batters['avg'],batters['strike_rate'],color='red',marker='+')
ax.set_title('Something')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike Rate')
fig.show()
# Out:
# C:\Users\91951\AppData\Local\Temp\ipykernel_24808\934772172.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#subplots

# %%
#3D plot 
batters 
fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'], marker='+')
ax.set_title('IPl batsman analysis')
ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('strike_rate')
# Out:
# Text(0.5, 0, 'strike_rate')

# %%
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]
fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z,color='red')

# %%
#d
#3d surface plots
# array into matrix
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx, yy = np.meshgrid(x,y)
(100, 100)
x = xx**2 + yy**2
z.shape
(100, 100)
fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       7 (100, 100)
#       8 x = xx**2 + yy**2
# ----> 9 z.shape
#      10 (100, 100)
#      11 fig = plt.figure(figsize=(12,8))
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function to plot (e.g., z = f(x, y))
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Create grid coordinates for x and y
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)

# Compute z values for each (x, y) pair
Z = f(X, Y)

# Create the contour plot
plt.contour(X, Y, Z, levels=10, cmap='viridis')

# Add labels and title
plt.colorbar()  # Add color bar to show the levels of the contours
plt.title("Contour Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()
